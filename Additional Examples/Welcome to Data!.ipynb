# %%
# LEOKA_ASSAULT_TIME_WEAPON_INJURY_1995_2021.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('LEOKA_ASSAULT_TIME_WEAPON_INJURY_1995_2021.csv')
df.head()
# Out:
#    DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR   DIVISION_NAME  \
# 0       1995       Abbeville             NaN         GA  South Atlantic
# 1       1995       Abbeville             NaN         SC  South Atlantic
# 2       1995       Abbeville             NaN         SC  South Atlantic
# 3       1995        Aberdeen             NaN         ID        Mountain
# 4       1995        Aberdeen             NaN         MD  South Atlantic
#
#   REGION_NAME AGENCY_TYPE_NAME                     POPULATION_GROUP_DESC  \
# 0       South             City                        Cities under 2,500
# 1       South             City              Cities from 2,500 thru 9,999
# 2       South           County  Non-MSA counties from 10,000 thru 24,999
# 3        West             City                        Cities under 2,500
# 4       South             City            Cities from 10,000 thru 24,999
#
#   COUNTY_NAME  TIME_0001_0200_CNT  ...  FIREARM_INJURY_CNT  \
# ...

# %%
df.tail()
# Out:
#         DATA_YEAR                       PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 311465       2021  Medical University of South Carolina             NaN
# 311466       2021                             Pineville             NaN
# 311467       2021                         Ross Township             NaN
# 311468       2021                         West Columbia             NaN
# 311469       2021                              Tualatin             NaN
#
#        STATE_ABBR       DIVISION_NAME REGION_NAME       AGENCY_TYPE_NAME  \
# 311465         SC      South Atlantic       South  University or College
# 311466         NC      South Atlantic       South                   City
# 311467         OH  East North Central     Midwest                   City
# 311468         SC      South Atlantic       South                   City
# 311469         OR             Pacific        West                   City
#
#                  POPULATION_GROUP_DESC            COUNTY_NAME  \
# ...

# %%
df.sample(5)
# Out:
#         DATA_YEAR      PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR  \
# 27474        1997               Slaton             NaN         TX
# 125251       2006      Bloomsburg Town             NaN         PA
# 50216        1999           Tabor City             NaN         NC
# 52645        2000  Bridgeport Township             NaN         MI
# 211263       2012     Marshall Village             NaN         WI
#
#              DIVISION_NAME REGION_NAME AGENCY_TYPE_NAME  \
# 27474   West South Central       South             City
# 125251     Middle Atlantic   Northeast             City
# 50216       South Atlantic       South             City
# 52645   East North Central     Midwest             City
# 211263  East North Central     Midwest             City
#
#                  POPULATION_GROUP_DESC COUNTY_NAME  TIME_0001_0200_CNT  ...  \
# 27474     Cities from 2,500 thru 9,999     LUBBOCK                   1  ...
# ...

# %%
df.head()
# Out:
#    DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR   DIVISION_NAME  \
# 0       1995       Abbeville             NaN         GA  South Atlantic
# 1       1995       Abbeville             NaN         SC  South Atlantic
# 2       1995       Abbeville             NaN         SC  South Atlantic
# 3       1995        Aberdeen             NaN         ID        Mountain
# 4       1995        Aberdeen             NaN         MD  South Atlantic
#
#   REGION_NAME AGENCY_TYPE_NAME                     POPULATION_GROUP_DESC  \
# 0       South             City                        Cities under 2,500
# 1       South             City              Cities from 2,500 thru 9,999
# 2       South           County  Non-MSA counties from 10,000 thru 24,999
# 3        West             City                        Cities under 2,500
# 4       South             City            Cities from 10,000 thru 24,999
#
#   COUNTY_NAME  TIME_0001_0200_CNT  ...  FIREARM_INJURY_CNT  \
# ...

# %%
df.shape
# Out:
# (311470, 31)

# %%
df.columns
# Out:
# Index(['DATA_YEAR', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT', 'STATE_ABBR',
#        'DIVISION_NAME', 'REGION_NAME', 'AGENCY_TYPE_NAME',
#        'POPULATION_GROUP_DESC', 'COUNTY_NAME', 'TIME_0001_0200_CNT',
#        'TIME_0201_0400_CNT', 'TIME_0401_0600_CNT', 'TIME_0601_0800_CNT',
#        'TIME_0801_1000_CNT', 'TIME_1001_1200_CNT', 'TIME_1201_1400_CNT',
#        'TIME_1401_1600_CNT', 'TIME_1601_1800_CNT', 'TIME_1801_2000_CNT',
#        'TIME_2001_2200_CNT', 'TIME_2201_0000_CNT', 'FIREARM_INJURY_CNT',
#        'FIREARM_NO_INJURY_CNT', 'KNIFE_INJURY_CNT', 'KNIFE_NO_INJURY_CNT',
#        'HANDS_FISTS_FEET_INJURY_CNT', 'HANDS_FISTS_FEET_NO_INJURY_CNT',
#        'OTHER_INJURY_CNT', 'OTHER_NO_INJURY_CNT', 'LEOKA_FELONY_KILLED',
#        'LEOKA_ACCIDENT_KILLED'],
#       dtype='object')

# %%
df.dtypes
# Out:
# DATA_YEAR                          int64
# PUB_AGENCY_NAME                   object
# PUB_AGENCY_UNIT                   object
# STATE_ABBR                        object
# DIVISION_NAME                     object
# REGION_NAME                       object
# AGENCY_TYPE_NAME                  object
# POPULATION_GROUP_DESC             object
# COUNTY_NAME                       object
# TIME_0001_0200_CNT                 int64
# TIME_0201_0400_CNT                 int64
# TIME_0401_0600_CNT                 int64
# TIME_0601_0800_CNT                 int64
# TIME_0801_1000_CNT                 int64
# TIME_1001_1200_CNT                 int64
# TIME_1201_1400_CNT                 int64
# TIME_1401_1600_CNT                 int64
# TIME_1601_1800_CNT                 int64
# TIME_1801_2000_CNT                 int64
# TIME_2001_2200_CNT                 int64
# TIME_2201_0000_CNT                 int64
# FIREARM_INJURY_CNT                 int64
# FIREARM_NO_INJURY_CNT              int64
# ...

# %%
df['DATA_YEAR'].value_counts()
# Out:
# 2016    15138
# 2015    14400
# 2014    14226
# 2010    14038
# 2013    13965
# 2012    13836
# 2009    13813
# 2011    13801
# 2008    13014
# 2007    12679
# 2004    12596
# 2003    12474
# 2005    12420
# 2002    12324
# 2006    12253
# 2001    12005
# 1999    11684
# 2000    10814
# 1995    10468
# 1997    10140
# 1998    10044
# 1996     9405
# 2021     9377
# 2018     7499
# 2017     7312
# 2019     6118
# 2020     5627
# Name: DATA_YEAR, dtype: int64

# %%
df['DATA_YEAR'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['HANDS_FISTS_FEET_NO_INJURY_CNT'].hist()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR   DIVISION_NAME  \
# 0       1995       Abbeville             NaN         GA  South Atlantic
# 1       1995       Abbeville             NaN         SC  South Atlantic
# 2       1995       Abbeville             NaN         SC  South Atlantic
# 3       1995        Aberdeen             NaN         ID        Mountain
# 4       1995        Aberdeen             NaN         MD  South Atlantic
#
#   REGION_NAME AGENCY_TYPE_NAME                     POPULATION_GROUP_DESC  \
# 0       South             City                        Cities under 2,500
# 1       South             City              Cities from 2,500 thru 9,999
# 2       South           County  Non-MSA counties from 10,000 thru 24,999
# 3        West             City                        Cities under 2,500
# 4       South             City            Cities from 10,000 thru 24,999
#
#   COUNTY_NAME  TIME_0001_0200_CNT  ...  FIREARM_INJURY_CNT  \
# ...

# %%
df.loc[5:10]
# Out:
#     DATA_YEAR    PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR  \
# 5        1995           Aberdeen             NaN         MS
# 6        1995           Aberdeen             NaN         NC
# 7        1995           Aberdeen             NaN         SD
# 8        1995           Aberdeen             NaN         WA
# 9        1995  Aberdeen Township             NaN         NJ
# 10       1995          Abernathy             NaN         TX
#
#          DIVISION_NAME REGION_NAME AGENCY_TYPE_NAME  \
# 5   East South Central       South             City
# 6       South Atlantic       South             City
# 7   West North Central     Midwest             City
# 8              Pacific        West             City
# 9      Middle Atlantic   Northeast             City
# 10  West South Central       South             City
#
#              POPULATION_GROUP_DESC    COUNTY_NAME  TIME_0001_0200_CNT  ...  \
# 5     Cities from 2,500 thru 9,999         MONROE                   0  ...
# ...

# %%
df["DATA_YEAR"]
# Out:
# 0         1995
# 1         1995
# 2         1995
# 3         1995
# 4         1995
#           ...
# 311465    2021
# 311466    2021
# 311467    2021
# 311468    2021
# 311469    2021
# Name: DATA_YEAR, Length: 311470, dtype: int64

# %%
df[["DATA_YEAR", "PUB_AGENCY_NAME", "STATE_ABBR"]]
# Out:
#         DATA_YEAR                       PUB_AGENCY_NAME STATE_ABBR
# 0            1995                             Abbeville         GA
# 1            1995                             Abbeville         SC
# 2            1995                             Abbeville         SC
# 3            1995                              Aberdeen         ID
# 4            1995                              Aberdeen         MD
# ...           ...                                   ...        ...
# 311465       2021  Medical University of South Carolina         SC
# 311466       2021                             Pineville         NC
# 311467       2021                         Ross Township         OH
# 311468       2021                         West Columbia         SC
# 311469       2021                              Tualatin         OR
#
# [311470 rows x 3 columns]

# %%
df.iloc[0:4,0:3]
# Out:
#    DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT
# 0       1995       Abbeville             NaN
# 1       1995       Abbeville             NaN
# 2       1995       Abbeville             NaN
# 3       1995        Aberdeen             NaN

# %%
df.at[0, 'DATA_YEAR']
# Out:
# 1995

# %%
df.head()
# Out:
#    DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR   DIVISION_NAME  \
# 0       1995       Abbeville             NaN         GA  South Atlantic
# 1       1995       Abbeville             NaN         SC  South Atlantic
# 2       1995       Abbeville             NaN         SC  South Atlantic
# 3       1995        Aberdeen             NaN         ID        Mountain
# 4       1995        Aberdeen             NaN         MD  South Atlantic
#
#   REGION_NAME AGENCY_TYPE_NAME                     POPULATION_GROUP_DESC  \
# 0       South             City                        Cities under 2,500
# 1       South             City              Cities from 2,500 thru 9,999
# 2       South           County  Non-MSA counties from 10,000 thru 24,999
# 3        West             City                        Cities under 2,500
# 4       South             City            Cities from 10,000 thru 24,999
#
#   COUNTY_NAME  TIME_0001_0200_CNT  ...  FIREARM_INJURY_CNT  \
# ...

# %%
df.query("DATA_YEAR == 1995 and STATE_ABBR == 'PA' and AGENCY_TYPE_NAME == 'State Police' and OTHER_INJURY_CNT > 0")
# Out:
#       DATA_YEAR PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR    DIVISION_NAME  \
# 8614       1995   State Police:  Luzerne County         PA  Middle Atlantic
#
#      REGION_NAME AGENCY_TYPE_NAME                 POPULATION_GROUP_DESC  \
# 8614   Northeast     State Police  MSA counties from 25,000 thru 99,999
#
#      COUNTY_NAME  TIME_0001_0200_CNT  ...  FIREARM_INJURY_CNT  \
# 8614     LUZERNE                   2  ...                   0
#
#       FIREARM_NO_INJURY_CNT  KNIFE_INJURY_CNT  KNIFE_NO_INJURY_CNT  \
# 8614                      0                 0                    0
#
#       HANDS_FISTS_FEET_INJURY_CNT  HANDS_FISTS_FEET_NO_INJURY_CNT  \
# 8614                            3                               3
#
#       OTHER_INJURY_CNT  OTHER_NO_INJURY_CNT  LEOKA_FELONY_KILLED  \
# 8614                 1                    0                    0
#
#       LEOKA_ACCIDENT_KILLED
# 8614                      0
#
# [1 rows x 31 columns]

# %%
df.query("DATA_YEAR == 1995").sort_values('STATE_ABBR', ascending=False)
# Out:
#       DATA_YEAR        PUB_AGENCY_NAME PUB_AGENCY_UNIT STATE_ABBR  \
# 6711       1995            Pine Bluffs             NaN         WY
# 7250       1995           Rock Springs             NaN         WY
# 3236       1995                 Goshen             NaN         WY
# 4627       1995                 Lander             NaN         WY
# 7065       1995                Rawlins             NaN         WY
# ...         ...                    ...             ...        ...
# 7812       1995               Soldotna             NaN         AK
# 3887       1995                  Homer             NaN         AK
# 4331       1995                  Kenai             NaN         AK
# 71         1995  Alaska State Troopers             NaN         AK
# 1918       1995                  Craig             NaN         AK
#
#      DIVISION_NAME REGION_NAME AGENCY_TYPE_NAME  \
# 6711      Mountain        West             City
# 7250      Mountain        West             City
# ...

# %%
df.query("DATA_YEAR == 1995").sort_values('STATE_ABBR', ascending=False)['STATE_ABBR'].value_counts()
# Out:
# TX    904
# CA    714
# NY    665
# NJ    508
# NC    476
# KY    470
# MI    460
# FL    428
# GA    359
# VA    342
# WI    326
# MN    301
# WV    297
# OK    286
# OH    275
# MA    250
# NB    239
# AL    210
# IN    208
# WA    205
# SC    198
# AR    187
# OR    186
# MO    185
# IA    181
# LA    155
# MD    148
# CO    137
# TN    133
# ME    126
# ID    107
# UT    101
# CT     99
# AZ     81
# NH     70
# ND     68
# WY     64
# VT     51
# MS     47
# SD     47
# NM     45
# RI     45
# NV     25
# AK     25
# PA     16
# HI      5
# IL      4
# MT      4
# KS      2
# FS      1
# DE      1
# DC      1
# Name: STATE_ABBR, dtype: int64

# %%
df.query("DATA_YEAR == 1995").sort_values('STATE_ABBR', ascending=False)['STATE_ABBR'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='STATE_ABBR'>

# %%
df.isnull().sum()
# Out:
# DATA_YEAR                              0
# PUB_AGENCY_NAME                        0
# PUB_AGENCY_UNIT                   269734
# STATE_ABBR                             0
# DIVISION_NAME                          0
# REGION_NAME                            0
# AGENCY_TYPE_NAME                       0
# POPULATION_GROUP_DESC                  0
# COUNTY_NAME                         3861
# TIME_0001_0200_CNT                     0
# TIME_0201_0400_CNT                     0
# TIME_0401_0600_CNT                     0
# TIME_0601_0800_CNT                     0
# TIME_0801_1000_CNT                     0
# TIME_1001_1200_CNT                     0
# TIME_1201_1400_CNT                     0
# TIME_1401_1600_CNT                     0
# TIME_1601_1800_CNT                     0
# TIME_1801_2000_CNT                     0
# TIME_2001_2200_CNT                     0
# TIME_2201_0000_CNT                     0
# FIREARM_INJURY_CNT                     0
# FIREARM_NO_INJURY_CNT                  0
# ...

# %%
df.dtypes
# Out:
# DATA_YEAR                          int64
# PUB_AGENCY_NAME                   object
# PUB_AGENCY_UNIT                   object
# STATE_ABBR                        object
# DIVISION_NAME                     object
# REGION_NAME                       object
# AGENCY_TYPE_NAME                  object
# POPULATION_GROUP_DESC             object
# COUNTY_NAME                       object
# TIME_0001_0200_CNT                 int64
# TIME_0201_0400_CNT                 int64
# TIME_0401_0600_CNT                 int64
# TIME_0601_0800_CNT                 int64
# TIME_0801_1000_CNT                 int64
# TIME_1001_1200_CNT                 int64
# TIME_1201_1400_CNT                 int64
# TIME_1401_1600_CNT                 int64
# TIME_1601_1800_CNT                 int64
# TIME_1801_2000_CNT                 int64
# TIME_2001_2200_CNT                 int64
# TIME_2201_0000_CNT                 int64
# FIREARM_INJURY_CNT                 int64
# FIREARM_NO_INJURY_CNT              int64
# ...

# %%
df['LEOKA_ACCIDENT_KILLED'].plot.box()
# Out:
# <AxesSubplot:>
